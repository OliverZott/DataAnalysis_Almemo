# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
wl = np.zeros((781-380,2))
#wl[i] = [i+380, -1]
wl.shape
for i in range(401):
    wl[i] = [i+380, -1]
    
wl
# Out:
# array([[380.,  -1.],
#        [381.,  -1.],
#        [382.,  -1.],
#        [383.,  -1.],
#        [384.,  -1.],
#        [385.,  -1.],
#        [386.,  -1.],
#        [387.,  -1.],
#        [388.,  -1.],
#        [389.,  -1.],
#        [390.,  -1.],
#        [391.,  -1.],
#        [392.,  -1.],
#        [393.,  -1.],
#        [394.,  -1.],
#        [395.,  -1.],
#        [396.,  -1.],
#        [397.,  -1.],
#        [398.,  -1.],
#        [399.,  -1.],
#        [400.,  -1.],
#        [401.,  -1.],
#        [402.,  -1.],
#        [403.,  -1.],
#        [404.,  -1.],
#        [405.,  -1.],
#        [406.,  -1.],
#        [407.,  -1.],
#        [408.,  -1.],
#        [409.,  -1.],
#        [410.,  -1.],
#        [411.,  -1.],
#        [412.,  -1.],
#        [413.,  -1.],
#        [414.,  -1.],
#        [415.,  -1.],
#        [416.,  -1.],
#        [417.,  -1.],
#        [418.,  -1.],
#        [419.,  -1.],
#        [420.,  -1.],
#        [421.,  -1.],
#        [422.,  -1.],
# ...

# %%
wl[0] = [17,12]
wl
# Out:
# array([[ 17.,  12.],
#        [381.,  -1.],
#        [382.,  -1.],
#        [383.,  -1.],
#        [384.,  -1.],
#        [385.,  -1.],
#        [386.,  -1.],
#        [387.,  -1.],
#        [388.,  -1.],
#        [389.,  -1.],
#        [390.,  -1.],
#        [391.,  -1.],
#        [392.,  -1.],
#        [393.,  -1.],
#        [394.,  -1.],
#        [395.,  -1.],
#        [396.,  -1.],
#        [397.,  -1.],
#        [398.,  -1.],
#        [399.,  -1.],
#        [400.,  -1.],
#        [401.,  -1.],
#        [402.,  -1.],
#        [403.,  -1.],
#        [404.,  -1.],
#        [405.,  -1.],
#        [406.,  -1.],
#        [407.,  -1.],
#        [408.,  -1.],
#        [409.,  -1.],
#        [410.,  -1.],
#        [411.,  -1.],
#        [412.,  -1.],
#        [413.,  -1.],
#        [414.,  -1.],
#        [415.,  -1.],
#        [416.,  -1.],
#        [417.,  -1.],
#        [418.,  -1.],
#        [419.,  -1.],
#        [420.,  -1.],
#        [421.,  -1.],
#        [422.,  -1.],
# ...

# %%
arr = np.array(lst)
type(arr)
print(arr)
# Out:
# [1 2 3 4 5]
